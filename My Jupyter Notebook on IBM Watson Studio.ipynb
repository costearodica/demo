# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## **Rodica Costea**
#  Data Scientist Financial Services

# %% [markdown]
# ## *I am fascinated by the way valuable insights can be generated from vast amount of data.*

# %% [markdown]
# Code below will print Thank you very much IBM for a great course

# %%
print("Thank you very much IBM for a great course")
# Out:
# Thank you very much IBM for a great course

# %% [markdown]
# #### here are some topics I enjoyed so far in this course
#
# 1. Jupyter notebooks
#
# 2. RStudio
#
# 3. IBM Watson Studio
